# %%
from chefboost import Chefboost as chef
import pandas as pd

# %%
df = pd.read_csv("bank-full.csv")

# %%
config = {'algorithm': 'C4.5'}

# %%
model = chef.fit(df, config)
# Out:
# Expected: Decision, Existing:  age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"Decision"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-98dc13e48d21> in <module>
# ----> 1 model = chef.fit(df, config)
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\Chefboost.py in fit(df, config)
#      23         if target_label != 'Decision':
#      24                 print("Expected: Decision, Existing: ",target_label)
# ---> 25                 raise ValueError('Please confirm that name of the target column is "Decision" and it is put to the right in pandas data frame')
#      26
#      27         #------------------------
#
# ValueError: Please confirm that name of the target column is "Decision" and it is put to the right in pandas data frame

# %%
df.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...
# 1  44;"technician";"single";"secondary";"no";29;"...
# 2  33;"entrepreneur";"married";"secondary";"no";2...
# 3  47;"blue-collar";"married";"unknown";"no";1506...
# 4  33;"unknown";"single";"unknown";"no";1;"no";"n...

# %%
df1 = pd.read_csv('bank.csv', sep= ';')
num_col = len(list(df1.columns))
pd.set_option('display.max_columns', num_col * 3)
df1.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"Decision"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
df = pd.read_csv('bank-additional/bank-additional/bank-additional-full.csv', sep= ';')
num_col = len(list(df.columns))
pd.set_option('display.max_columns', num_col * 3)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           1.1          93.994          -36.4      4.857       5191.0  no
# 1           1.1          93.994          -36.4      4.857       5191.0  no
# 2           1.1          93.994          -36.4      4.857       5191.0  no
# 3           1.1          93.994          -36.4      4.857       5191.0  no
# 4           1.1          93.994          -36.4      4.857       5191.0  no

# %%
df = pd.read_csv('bank-additional/bank-additional/bank-additional-full1.csv', sep= ';')
num_col = len(list(df.columns))
pd.set_option('display.max_columns', num_col * 3)
df.head()
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"Decision"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...

# %%
df = pd.read_csv('bank-additional/bank-additional/bank-additional-full1.csv', sep= ';')
num_col = len(list(df.columns))
pd.set_option('display.max_columns', num_col * 3)
df.head()
# Out:
#   age;"job";"marital";"education";"default";"housing";"loan";"contact";"month";"day_of_week";"duration";"campaign";"pdays";"previous";"poutcome";"emp.var.rate";"cons.price.idx";"cons.conf.idx";"euribor3m";"nr.employed";"Decision"
# 0  56;"housemaid";"married";"basic.4y";"no";"no";...
# 1  57;"services";"married";"high.school";"unknown...
# 2  37;"services";"married";"high.school";"no";"ye...
# 3  40;"admin.";"married";"basic.6y";"no";"no";"no...
# 4  56;"services";"married";"high.school";"no";"no...

# %%
df = pd.read_csv('bank-additional/bank-additional/bank-additional-full.csv', sep= ';')
num_col = len(list(df.columns))
pd.set_option('display.max_columns', num_col * 3)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           1.1          93.994          -36.4      4.857       5191.0  no
# 1           1.1          93.994          -36.4      4.857       5191.0  no
# 2           1.1          93.994          -36.4      4.857       5191.0  no
# 3           1.1          93.994          -36.4      4.857       5191.0  no
# 4           1.1          93.994          -36.4      4.857       5191.0  no

# %%
df1 = df.rename(columns={"y": "Decision"})

# %%
config = {'algorithm': 'C4.5'}

# %%
model = chef.fit(df1, config)
# Out:
# C4.5  tree is going to be built...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-91c7109ff56f> in <module>
# ----> 1 model = chef.fit(df1, config)
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\Chefboost.py in fit(df, config)
#     155
#     156 		trees = Training.buildDecisionTree(df,root,file, config, dataset_features
# --> 157 			, 0, 0, 'root')
#     158
#     159         print("finished in ",time.time() - begin," seconds")
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     349                 if enableParallelism != True:
#     350 			createBranch(config, current_class, subdataset, numericColumn, branch_index
# --> 351 				, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     352                 else:
#     353 			input_params.append((config, current_class, subdataset, numericColumn, branch_index
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in createBranch(config, current_class, subdataset, numericColumn, branch_index, winner_index, root, parents, file, dataset_features, num_of_instances, metric)
#     287
#     288 		buildDecisionTree(subdataset, root, file, config, dataset_features
# --> 289 			, root-1, leaf_id, parents)
#     290
#     291                 root = tmp_root * 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\training\Training.py in buildDecisionTree(df, root, file, config, dataset_features, parent_level, leaf_id, parents)
#     365
#     366                 if enableParallelism != True:
# --> 367                         functions.storeRule(file,(functions.formatRule(root), "else:"))
#     368                         functions.storeRule(file,(functions.formatRule(root+1), else_decision))
#     369                 else: #parallelism
#
# C:\ProgramData\Anaconda3\lib\site-packages\chefboost\commons\functions.py in storeRule(file, content)
#      31
#      32 def storeRule(file,content):
# ---> 33         f = open(file, "a+")
#      34         f.writelines(content)
#      35         f.writelines("\n")
#
# C:\ProgramData\Anaconda3\lib\_bootlocale.py in getpreferredencoding(do_setlocale)
#       9
#      10 if sys.platform.startswith("win"):
# ---> 11     def getpreferredencoding(do_setlocale=True):
#      12         if sys.flags.utf8_mode:
#      13             return 'UTF-8'
#
# KeyboardInterrupt:
